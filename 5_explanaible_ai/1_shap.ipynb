# %% [markdown]
# # Explanaible AI - Shap
# Documentation:
# - https://shap.readthedocs.io/en/latest/example_notebooks/overviews/An%20introduction%20to%20explainable%20AI%20with%20Shapley%20values.html

# %%
import os
# fix root path to save outputs
actual_path = os.path.abspath(os.getcwd())
list_root_path = actual_path.split('\\')[:-1]
root_path = '\\'.join(list_root_path)
os.chdir(root_path)
print('root path: ', root_path)
# Out:
# root path:  D:\github-mi-repo\Offline-Evaluation-ML-Regression

# %% [markdown]
# ## RUN

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt

import plotly.graph_objs as go
from plotly.subplots import make_subplots
import plotly.express as px

# shap
import shap

# %% [markdown]
# ### 0. Global params

# %%
# define folder where the models were saved. There are the same models accepted by gurobi but the feature eng changed

# list of folder with models = ['basic', 'scaler', 'poly_2', 'poly_3']
folder_models = 'basic'

# %% [markdown]
# ### 1. Load data

# %%
### DEFINE LIST FEARTURES - TARGET (order data to have the same order in the features always)
list_features = ['AveOccup', 'Latitude', 'Population', 'AveBedrms', 'HouseAge', 'Longitude', 'AveRooms', 'MedInc']
target = 'Price'

# %%
### LOAD DATA
X_train = pd.read_pickle('artifacts/data/X_train.pkl')
X_test = pd.read_pickle('artifacts/data/X_test.pkl')
y_train = pd.read_pickle('artifacts/data/y_train.pkl')
y_test = pd.read_pickle('artifacts/data/y_test.pkl')

# %%
print('shape data')
print('\n\n TRAIN')
print('X_train: ', X_train.shape)
print('y_train: ', y_train.shape)

print('\n\n TEST')
print('X_test: ', X_test.shape)
print('y_test: ', y_test.shape)
# Out:
# shape data
#
#
#  TRAIN
# X_train:  (14540, 8)
# y_train:  (14540, 1)
#
#
#  TEST
# X_test:  (3636, 8)
# y_test:  (3636, 1)

# %%
# sample x train to run fast codes
X_train = X_train[0:1000]
X_train.shape
# Out:
# (1000, 8)

# %% [markdown]
# ### 2. Load Models
# Load all the models in a dictory

# %%
## define list of models - list to have always the same order.
#### In this example, the strings in the list are the same with the models were saved
list_models_names = [
    "lr",
    "ridge",
    "lasso",
    
    "tree_simple",
    "tree_default",
    
    "rf_simple",
    "rf_default",

    "gb_simple",
    "gb_default",

    "xgb_simple",
    "xgb_default",

    "mlp_simple",
    "mlp_default"
]

# %%
# define path to folder models
path_folder_models = f'artifacts/models/{folder_models}/'

# %%
### load models
dict_models = {}
for model_name in list_models_names:
    print(f'loading model: {model_name}')
    path_model = path_folder_models + f'{model_name}.pkl'
    with open(path_model, 'rb') as artifact:
        dict_models[model_name] = pickle.load(artifact)
# Out:
# loading model: lr
# loading model: ridge
# loading model: lasso
# loading model: tree_simple
# loading model: tree_default
# loading model: rf_simple
# loading model: rf_default
# loading model: gb_simple
# loading model: gb_default
# loading model: xgb_simple
# loading model: xgb_default
# loading model: mlp_simple
# loading model: mlp_default

# %%
# select model example
model = dict_models['lr']

# %% [markdown]
# ### 3. Sample data

# %%
# sample - run fast
X_train_100 = shap.utils.sample(X_train, 100)
y_train_100 = shap.utils.sample(y_train, 100)

# %%
X_train.shape
# Out:
# (1000, 8)

# %%
X_train_100.shape
# Out:
# (100, 8)

# %% [markdown]
# ### 4. Partial Dependence Plot
# **Main**
#
# To understand a feature’s importance in a model, it is necessary to understand both how changing that feature impacts the model’s output, and also the distribution of that feature’s values.
#
#
# **Explication plot**
#
# - Show the distribution of feature values as a histogram on the x-axis
# - The gray horizontal line in the plot above represents the expected value of the model
# - The vertical gray line represents the average value of the feature
# - Note that the blue partial dependence plot line (which is the average value of the model output when we fix the median income feature to a given value) always passes through the intersection of the two gray expected value lines. We can consider this intersection point as the “center” of the partial dependence plot with respect to the data distribution
#
# **Documentation**
#
# - https://shap-lrjball.readthedocs.io/en/latest/generated/shap.partial_dependence_plot.html

# %%
# select a feature
feature = "MedInc"

# %%
shap.partial_dependence_plot(
    feature,
    model.predict,
    X_train_100,
    ice=False,
    model_expected_value=True,
    feature_expected_value=True,
)

# %% [markdown]
# **Aditional**
# When we are explaining a prediction
# , the SHAP value for a specific feature
#  is just the difference between the expected model output and the partial dependence plot at the feature’s value

# %%
# compute the SHAP values for the linear model
explainer = shap.Explainer(model.predict, X_train_100)
shap_values = explainer(X_train)
shap_values
# Out:
# ExactExplainer explainer: 1001it [00:18, 36.51it/s]
# .values =
# array([[ 0.17101742,  0.63037096, -0.60584264, ...,  0.19573562,
#         -0.03145708,  0.06316537],
#        [ 0.37454316, -0.83551226,  1.08051106, ..., -0.18543343,
#          0.00665597,  0.30715179],
#        [-0.16791141,  0.15684127, -0.30470805, ..., -1.01302075,
#         -0.04199286,  0.11738457],
#        ...,
#        [-0.09344562, -0.24257073, -0.2244055 , ..., -0.51377459,
#         -0.01309143,  0.04961057],
#        [-0.06216034,  0.81566519, -0.69016033, ...,  1.02032986,
#          0.01989766, -0.07238264],
#        [ 0.15579965, -0.83962991,  1.08051106, ...,  0.16375953,
#         -0.01430045,  0.30715179]])
#
# .base_values =
# array([[2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607],
#        [2.05572607]])
#
# .data =
# array([[ 2.49595687e+00,  3.42200000e+01, -1.18240000e+02, ...,
#          4.15230000e+00,  9.26000000e+02,  3.40000000e+01],
#        [ 1.98500000e+00,  3.77800000e+01, -1.22440000e+02, ...,
#          3.38820000e+00,  1.58800000e+03,  5.20000000e+01],
#        [ 3.34684685e+00,  3.53700000e+01, -1.18990000e+02, ...,
#          1.72920000e+00,  7.43000000e+02,  3.80000000e+01],
#        ...,
#        [ 3.15989848e+00,  3.63400000e+01, -1.19190000e+02, ...,
#          2.73000000e+00,  1.24500000e+03,  3.30000000e+01],
#        [ 3.08135593e+00,  3.37700000e+01, -1.18030000e+02, ...,
#          5.80530000e+00,  1.81800000e+03,  2.40000000e+01],
#        [ 2.53416149e+00,  3.77900000e+01, -1.22440000e+02, ...,
#          4.08820000e+00,  1.22400000e+03,  5.20000000e+01]])

# %%
# make a standard partial dependence plot
sample_ind = 20

# %%
# TRY TO SOLVE PROBLEMS
# reduce dimensions of .base_values. # REDUCE ONE DIMENTION from (1,1) to (1,)
shap_values_to_partial_plot = shap_values[sample_ind : sample_ind + 1, :]
shap_values_to_partial_plot.base_values = shap_values_to_partial_plot.base_values[0]  # from (1,1) to (1,)
shap_values_to_partial_plot
# Out:
# .values =
# array([[ 0.47222822, -1.17727716,  0.63884699, -0.11555343,  0.14720413,
#         -0.83173972, -0.04320188, -0.24859505]])
#
# .base_values =
# array([2.05572607])
#
# .data =
# array([[   1.73975904,   38.61      , -121.34      ,    0.97349398,
#            4.13493976,    2.0926    ,  722.        ,   11.        ]])

# %%
# partial dependence plot with shap values
shap.partial_dependence_plot(
    feature,
    model.predict,
    X_train_100,
    ice=False,
    model_expected_value=True,
    feature_expected_value=True,
    shap_values = shap_values[sample_ind : sample_ind + 1, :]  # plot a shap value
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 2
#       1 # partial dependence plot with shap values
# ----> 2 shap.partial_dependence_plot(
#       3     feature,
#       4     model.predict,
#       5     X_train_100,
#       6     ice=False,
#       7     model_expected_value=True,
#       8     feature_expected_value=True,
#       9     shap_values = shap_values[sample_ind : sample_ind + 1, :]  # plot a shap value
#      10 )
#
# File D:\Anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages\shap\plots\_partial_dependence.py:181, in partial_dependence(ind, model, data, xmin, xmax, npoints, feature_names, hist, model_expected_value, feature_expected_value, shap_values, ylabel, ice, ace_opacity, pd_opacity, pd_linewidth, ace_linewidth, ax, show)
#     165     ax1.axhline(model_expected_value, color="#999999", zorder=-1, linestyle="--", linewidth=1)
#     167 if shap_values is not None:
#     168     # vals = shap_values.values[:, ind]
#     169     # if shap_value_features is None:
#    (...)
#     179     # if isinstance(shap_value_features, pd.DataFrame):
#     180     #     shap_value_features = shap_value_features.values
# --> 181     markerline, stemlines, _ = ax1.stem(
#     182         shap_values.data[:,ind], shap_values.base_values + shap_values.values[:, ind],
#     183         bottom=shap_values.base_values,
#     184         markerfmt="o", basefmt=" ",
#     185     )
#     186     stemlines.set_edgecolors([red_rgb if v > 0 else blue_rgb for v in vals])
#     187     pl.setp(stemlines, 'zorder', -1)
#
# File D:\Anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages\matplotlib\__init__.py:1478, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1475 @functools.wraps(func)
#    1476 def inner(ax, *args, data=None, **kwargs):
#    1477     if data is None:
# -> 1478         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1480     bound = new_sig.bind(ax, *args, **kwargs)
#    1481     auto_label = (bound.arguments.get(label_namer)
#    1482                   or bound.kwargs.get(label_namer))
#
# File D:\Anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages\matplotlib\axes\_axes.py:3088, in Axes.stem(self, linefmt, markerfmt, basefmt, bottom, label, orientation, *args)
#    3082     baseline_y = [bottom, bottom]
#    3084 markerline, = self.plot(marker_x, marker_y,
#    3085                         color=markercolor, linestyle=markerstyle,
#    3086                         marker=markermarker, label="_nolegend_")
# -> 3088 baseline, = self.plot(baseline_x, baseline_y,
#    3089                       color=basecolor, linestyle=basestyle,
#    3090                       marker=basemarker, label="_nolegend_")
#    3092 stem_container = StemContainer((markerline, stemlines, baseline),
#    3093                                label=label)
#    3094 self.add_container(stem_container)
#
# File D:\Anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages\matplotlib\axes\_axes.py:1721, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1478 """
#    1479 Plot y versus x as lines and/or markers.
#    1480
#    (...)
#    1718 (``'green'``) or hex strings (``'#008000'``).
#    1719 """
#    1720 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1721 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1722 for line in lines:
#    1723     self.add_line(line)
#
# File D:\Anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages\matplotlib\axes\_base.py:303, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     301     this += args[0],
#     302     args = args[1:]
# --> 303 yield from self._plot_args(
#     304     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File D:\Anaconda\envs\data-science-python-3-10-explanaible-ai\lib\site-packages\matplotlib\axes\_base.py:502, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     499     raise ValueError(f"x and y must have same first dimension, but "
#     500                      f"have shapes {x.shape} and {y.shape}")
#     501 if x.ndim > 2 or y.ndim > 2:
# --> 502     raise ValueError(f"x and y can be no greater than 2D, but have "
#     503                      f"shapes {x.shape} and {y.shape}")
#     504 if x.ndim == 1:
#     505     x = x[:, np.newaxis]
#
# ValueError: x and y can be no greater than 2D, but have shapes (2,) and (2, 1, 1)

# %%
# why this the code is failing
shap_values[sample_ind : sample_ind + 1, :]
# Out:
# .values =
# array([[ 0.47222822, -1.17727716,  0.63884699, -0.11555343,  0.14720413,
#         -0.83173972, -0.04320188, -0.24859505]])
#
# .base_values =
# array([[2.05572607]])
#
# .data =
# array([[   1.73975904,   38.61      , -121.34      ,    0.97349398,
#            4.13493976,    2.0926    ,  722.        ,   11.        ]])

# %%
shap_values[sample_ind : sample_ind + 1, :].values.shape
# Out:
# (1, 8)

# %%
shap_values[sample_ind : sample_ind + 1, :].base_values.shape
# Out:
# (1, 1)

# %%
shap_values[sample_ind : sample_ind + 1, :].base_values
# Out:
# array([[2.05572607]])

# %%
shap_values[sample_ind : sample_ind + 1, :].data.shape
# Out:
# (1, 8)

# %%
shap.plots.scatter(shap_values[:, feature])

# %%
shap_values#[:, feature]

# %%
shap_values.values

# %%
shap_values.values[:, feature]

# %%
shap.plots.scatter(shap_values[:, "MedInc"])

# %% [markdown]
# # TODO: terminar de acuerdo a mi estudio de explanaible AI - termninar día viernes en la tarde. Migrar códigos viernes noche
